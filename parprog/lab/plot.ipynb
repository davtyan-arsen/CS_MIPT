# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %%
file = open("lab.txt", 'r')
line = file.readlines()

u = []
for i in range(0, len(line)):
    u.append(float(line[i]))

T = 5
X = 100
K = 50
M = 1000
tau = T / K
h = X / M

t_k = np.arange(0, T + tau, tau)
x_m = np.arange(0, X + h, h)


x = []
t = []

for i in range(0,len(t_k)):
    for j in x_m:
        x.append(j)
for i in t_k:
    for j in x_m:
        t.append(i)

fig = plt.figure(figsize = (15,10))
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.plot_trisurf(t, x, u, linewidth=0.2, antialiased=True)
ax.set_xlabel('t')
ax.set_ylabel('x')
ax.set_zlabel('u')
plt.show()
